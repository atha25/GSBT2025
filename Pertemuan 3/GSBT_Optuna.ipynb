# %% [markdown]
# # Overview Materi

# %% [markdown]
# Jelaskan perbedaan singkat antara grid, randomized, bayesian search cv dengan optuna menurut pemahamanmu
#
# source: https://www.youtube.com/watch?v=t-INgABWULw

# %% [markdown]
# Grid Search mencoba semua kombinasi parameter yang kita tentukan. Cara ini menjamin menemukan hasil terbaik dalam ruang parameter kecil, tapi akan sangat memakan waktu kalau kombinasi parameternya banyak. Sebaliknya, Random Search hanya mengambil sebagian kombinasi secara acak. Lebih cepat dan efisien, tapi ada kemungkinan kombinasi terbaik tidak terpilih.
#
# Bayesian Search lebih efisien karena memanfaatkan informasi dari percobaan sebelumnya untuk memutuskan parameter berikutnya. Sementara Optuna menawarkan pendekatan yang lebih modern: fleksibel, adaptif, dan bisa menghentikan percobaan yang kurang menjanjikan lebih awal. Hal ini membuat Optuna sering dipilih karena lebih praktis sekaligus hemat waktu.

# %% [markdown]
# # Import Data & Libraries

# %%
# jalankan hanya sekali
# !pip install optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 4.8 MB/s eta 0:00:00

# %%
# import library yang dibutuhkan di sini
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Data Preprocessing

# %%
# ubah variabel kategorik ke numerik
iris_mapping = {
    'setosa': 0,
    'versicolor': 1,
    'virginica': 2
}

df['species'] = df['species'].map(iris_mapping)

# %%
# subsetting peubah
X = df.drop(['species'], axis=1)
y = df['species']

# %% [markdown]
# # Dataset Splitting

# %%
# split dengan rasio 80:20
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=19
)

# %% [markdown]
# # Base Model Random Forest

# %%
# gunakan random forest classifier
rfc = RandomForestClassifier(random_state=69)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=69)

# %%
y_pred = rfc.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Precision: 1.000
# Recall: 1.000
# F1 Score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# # Optuna

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 10, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 32)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 32)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42)

    score = cross_val_score(model, X, y, n_jobs=-1, cv=5, scoring='accuracy')

    return score.mean()

# %% [markdown]
# Hyperparameter dapat disesuaikan dengan algoritma yang digunakan. Kali ini kita menggunakan Random Forest sehingga yang dapat kita select adalah *n_estimators, max_depth, min_samples_split,* dan *min_samples_leaf*

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler(seed=42))
# Out:
# [I 2025-10-04 14:45:19,455] A new study created in memory with name: no-name-486e3e47-ae38-4421-9a62-ec612fff1ed2

# %%
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-10-04 14:45:51,032] Trial 0 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 437, 'max_depth': 48, 'min_samples_split': 24, 'min_samples_leaf': 20}. Best is trial 0 with value: 0.9466666666666665.
# [I 2025-10-04 14:45:52,801] Trial 1 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 240, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 28}. Best is trial 0 with value: 0.9466666666666665.
# [I 2025-10-04 14:45:58,659] Trial 2 finished with value: 0.7666666666666667 and parameters: {'n_estimators': 641, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 32}. Best is trial 0 with value: 0.9466666666666665.
# [I 2025-10-04 14:46:05,196] Trial 3 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 850, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:07,956] Trial 4 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 374, 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:14,315] Trial 5 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 651, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 12}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:18,215] Trial 6 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 510, 'max_depth': 42, 'min_samples_split': 8, 'min_samples_leaf': 17}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:22,870] Trial 7 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 633, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:24,669] Trial 8 finished with value: 0.9133333333333333 and parameters: {'n_estimators': 158, 'max_depth': 48, 'min_samples_split': 31, 'min_samples_leaf': 26}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:28,306] Trial 9 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 374, 'max_depth': 14, 'min_samples_split': 23, 'min_samples_leaf': 15}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:29,881] Trial 10 finished with value: 0.8266666666666668 and parameters: {'n_estimators': 209, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 30}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:32,318] Trial 11 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 333, 'max_depth': 37, 'min_samples_split': 11, 'min_samples_leaf': 17}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:36,586] Trial 12 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 592, 'max_depth': 17, 'min_samples_split': 32, 'min_samples_leaf': 25}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:45,799] Trial 13 finished with value: 0.8400000000000001 and parameters: {'n_estimators': 946, 'max_depth': 46, 'min_samples_split': 20, 'min_samples_leaf': 30}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:47,285] Trial 14 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 179, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 11}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:50,761] Trial 15 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 450, 'max_depth': 21, 'min_samples_split': 27, 'min_samples_leaf': 12}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:54,671] Trial 16 finished with value: 0.9266666666666667 and parameters: {'n_estimators': 353, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 26}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:55,921] Trial 17 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 167, 'max_depth': 50, 'min_samples_split': 25, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.9533333333333334.
# [I 2025-10-04 14:46:57,264] Trial 18 finished with value: 0.96 and parameters: {'n_estimators': 104, 'max_depth': 43, 'min_samples_split': 23, 'min_samples_leaf': 24}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:04,334] Trial 19 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 794, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:12,152] Trial 20 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 877, 'max_depth': 35, 'min_samples_split': 12, 'min_samples_leaf': 3}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:14,931] Trial 21 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 380, 'max_depth': 23, 'min_samples_split': 24, 'min_samples_leaf': 21}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:22,976] Trial 22 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 899, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 23}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:28,656] Trial 23 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 785, 'max_depth': 33, 'min_samples_split': 25, 'min_samples_leaf': 16}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:33,917] Trial 24 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 570, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:35,315] Trial 25 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 128, 'max_depth': 36, 'min_samples_split': 11, 'min_samples_leaf': 17}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:41,923] Trial 26 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 917, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 25}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:44,174] Trial 27 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 306, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:52,591] Trial 28 finished with value: 0.9 and parameters: {'n_estimators': 937, 'max_depth': 43, 'min_samples_split': 21, 'min_samples_leaf': 28}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:47:58,532] Trial 29 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 824, 'max_depth': 17, 'min_samples_split': 29, 'min_samples_leaf': 18}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:06,184] Trial 30 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 827, 'max_depth': 46, 'min_samples_split': 11, 'min_samples_leaf': 4}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:08,432] Trial 31 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 305, 'max_depth': 27, 'min_samples_split': 27, 'min_samples_leaf': 28}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:09,245] Trial 32 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 106, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:10,761] Trial 33 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 207, 'max_depth': 23, 'min_samples_split': 31, 'min_samples_leaf': 11}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:16,226] Trial 34 finished with value: 0.76 and parameters: {'n_estimators': 567, 'max_depth': 38, 'min_samples_split': 13, 'min_samples_leaf': 32}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:23,414] Trial 35 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 967, 'max_depth': 20, 'min_samples_split': 17, 'min_samples_leaf': 10}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:26,099] Trial 36 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 356, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 17}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:27,916] Trial 37 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 146, 'max_depth': 21, 'min_samples_split': 30, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:30,420] Trial 38 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 230, 'max_depth': 30, 'min_samples_split': 32, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:35,665] Trial 39 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 705, 'max_depth': 41, 'min_samples_split': 9, 'min_samples_leaf': 24}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:38,870] Trial 40 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 431, 'max_depth': 35, 'min_samples_split': 21, 'min_samples_leaf': 18}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:40,428] Trial 41 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 181, 'max_depth': 44, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 18 with value: 0.96.
# [I 2025-10-04 14:48:42,365] Trial 42 finished with value: 0.9666666666666668 and parameters: {'n_estimators': 136, 'max_depth': 34, 'min_samples_split': 23, 'min_samples_leaf': 1}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:48:46,793] Trial 43 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 561, 'max_depth': 19, 'min_samples_split': 22, 'min_samples_leaf': 6}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:48:52,017] Trial 44 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 722, 'max_depth': 25, 'min_samples_split': 31, 'min_samples_leaf': 5}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:48:56,332] Trial 45 finished with value: 0.8800000000000001 and parameters: {'n_estimators': 407, 'max_depth': 14, 'min_samples_split': 30, 'min_samples_leaf': 29}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:00,359] Trial 46 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 332, 'max_depth': 37, 'min_samples_split': 27, 'min_samples_leaf': 18}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:04,598] Trial 47 finished with value: 0.8800000000000001 and parameters: {'n_estimators': 577, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 29}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:12,756] Trial 48 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 911, 'max_depth': 35, 'min_samples_split': 12, 'min_samples_leaf': 12}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:18,174] Trial 49 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 754, 'max_depth': 46, 'min_samples_split': 29, 'min_samples_leaf': 25}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:23,968] Trial 50 finished with value: 0.8800000000000001 and parameters: {'n_estimators': 678, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 29}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:29,112] Trial 51 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 646, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 22}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:29,960] Trial 52 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 104, 'max_depth': 16, 'min_samples_split': 19, 'min_samples_leaf': 23}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:35,162] Trial 53 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 687, 'max_depth': 19, 'min_samples_split': 24, 'min_samples_leaf': 8}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:39,741] Trial 54 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 393, 'max_depth': 40, 'min_samples_split': 22, 'min_samples_leaf': 28}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:45,162] Trial 55 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 692, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 12}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:47,801] Trial 56 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 338, 'max_depth': 20, 'min_samples_split': 32, 'min_samples_leaf': 13}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:49:56,215] Trial 57 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 903, 'max_depth': 35, 'min_samples_split': 26, 'min_samples_leaf': 17}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:01,008] Trial 58 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 619, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 24}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:04,258] Trial 59 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 352, 'max_depth': 10, 'min_samples_split': 22, 'min_samples_leaf': 6}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:12,189] Trial 60 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 947, 'max_depth': 49, 'min_samples_split': 30, 'min_samples_leaf': 12}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:13,074] Trial 61 finished with value: 0.8000000000000002 and parameters: {'n_estimators': 113, 'max_depth': 48, 'min_samples_split': 15, 'min_samples_leaf': 31}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:21,774] Trial 62 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 968, 'max_depth': 44, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:28,453] Trial 63 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 866, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 18}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:37,138] Trial 64 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 943, 'max_depth': 38, 'min_samples_split': 19, 'min_samples_leaf': 4}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:41,910] Trial 65 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 654, 'max_depth': 50, 'min_samples_split': 6, 'min_samples_leaf': 17}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:49,831] Trial 66 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 890, 'max_depth': 40, 'min_samples_split': 23, 'min_samples_leaf': 23}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:52,928] Trial 67 finished with value: 0.9266666666666667 and parameters: {'n_estimators': 423, 'max_depth': 22, 'min_samples_split': 27, 'min_samples_leaf': 26}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:50:59,837] Trial 68 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 881, 'max_depth': 47, 'min_samples_split': 17, 'min_samples_leaf': 17}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:06,394] Trial 69 finished with value: 0.9266666666666667 and parameters: {'n_estimators': 819, 'max_depth': 36, 'min_samples_split': 23, 'min_samples_leaf': 26}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:13,609] Trial 70 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 901, 'max_depth': 23, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:18,675] Trial 71 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 621, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 18}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:21,282] Trial 72 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 358, 'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:28,428] Trial 73 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 841, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 17}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:34,347] Trial 74 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 793, 'max_depth': 18, 'min_samples_split': 21, 'min_samples_leaf': 3}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:35,406] Trial 75 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 146, 'max_depth': 31, 'min_samples_split': 18, 'min_samples_leaf': 21}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:42,129] Trial 76 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 754, 'max_depth': 50, 'min_samples_split': 18, 'min_samples_leaf': 11}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:48,045] Trial 77 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 816, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:48,951] Trial 78 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 122, 'max_depth': 49, 'min_samples_split': 27, 'min_samples_leaf': 23}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:52,745] Trial 79 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 468, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:51:58,166] Trial 80 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 594, 'max_depth': 39, 'min_samples_split': 22, 'min_samples_leaf': 9}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:05,105] Trial 81 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 960, 'max_depth': 40, 'min_samples_split': 19, 'min_samples_leaf': 20}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:09,983] Trial 82 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 478, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 25}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:10,835] Trial 83 finished with value: 0.9666666666666668 and parameters: {'n_estimators': 112, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:17,150] Trial 84 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 870, 'max_depth': 38, 'min_samples_split': 16, 'min_samples_leaf': 4}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:22,147] Trial 85 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 542, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 14}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:25,745] Trial 86 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 459, 'max_depth': 35, 'min_samples_split': 21, 'min_samples_leaf': 2}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:28,846] Trial 87 finished with value: 0.8933333333333333 and parameters: {'n_estimators': 437, 'max_depth': 35, 'min_samples_split': 17, 'min_samples_leaf': 28}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:34,323] Trial 88 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 693, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 21}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:36,087] Trial 89 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 123, 'max_depth': 34, 'min_samples_split': 31, 'min_samples_leaf': 19}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:40,705] Trial 90 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 449, 'max_depth': 36, 'min_samples_split': 16, 'min_samples_leaf': 18}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:47,748] Trial 91 finished with value: 0.8800000000000001 and parameters: {'n_estimators': 948, 'max_depth': 25, 'min_samples_split': 31, 'min_samples_leaf': 29}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:50,848] Trial 92 finished with value: 0.96 and parameters: {'n_estimators': 276, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:52,231] Trial 93 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 185, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 11}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:58,501] Trial 94 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 861, 'max_depth': 10, 'min_samples_split': 27, 'min_samples_leaf': 10}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:52:59,978] Trial 95 finished with value: 0.8733333333333334 and parameters: {'n_estimators': 206, 'max_depth': 38, 'min_samples_split': 21, 'min_samples_leaf': 29}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:53:07,088] Trial 96 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 762, 'max_depth': 42, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:53:12,649] Trial 97 finished with value: 0.9466666666666665 and parameters: {'n_estimators': 776, 'max_depth': 43, 'min_samples_split': 32, 'min_samples_leaf': 14}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:53:16,580] Trial 98 finished with value: 0.8400000000000001 and parameters: {'n_estimators': 435, 'max_depth': 41, 'min_samples_split': 12, 'min_samples_leaf': 30}. Best is trial 42 with value: 0.9666666666666668.
# [I 2025-10-04 14:53:23,574] Trial 99 finished with value: 0.9533333333333334 and parameters: {'n_estimators': 873, 'max_depth': 27, 'min_samples_split': 25, 'min_samples_leaf': 25}. Best is trial 42 with value: 0.9666666666666668.

# %% [markdown]
# it may take a while... so just wait n see ^^
# <br>
# they recommend to set n_trials at 100 cz it seems there's no significant score increase after 100 trials (also inefficient too, you'll have to wait in a quite long time)

# %%
best_params = study.best_params
print(best_params)
# Out:
# {'n_estimators': 136, 'max_depth': 34, 'min_samples_split': 23, 'min_samples_leaf': 1}

# %% [markdown]
# Berikut hasil hyperparameter tuning dari Optuna

# %%
# cek hasil hyperparameter tuning dari Optuna
best_score = study.best_value
print(best_score)
# Out:
# 0.9666666666666668

# %% [markdown]
# # Random Forest Using Optuna

# %%
# simpan hasil best hyperparameter tuning ke variabel bari
n_estimators = best_params['n_estimators']
max_depth = best_params['max_depth']
min_samples_split = best_params['min_samples_split']
min_samples_leaf = best_params['min_samples_leaf']

# %%
best_model = RandomForestClassifier(
    n_estimators=n_estimators,
    max_depth=max_depth,
    min_samples_split=min_samples_split,
    min_samples_leaf=min_samples_leaf,
    random_state=42
)

best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=34, min_samples_split=23, n_estimators=136,
#                        random_state=42)

# %%
y_pred = best_model.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Precision: 1.000
# Recall: 1.000
# F1 Score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# Tidak terdapat kenaikan skor dengan sebelum menggunakan Optuna sebab skor yang dihasilkan melalui base model saja sudah bagus
